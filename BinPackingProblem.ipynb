# %%
import numpy as np
import random
import time
import pandas as pd

# %% [markdown]
# # Przygotowanie danych wejściowych

# %% [markdown]
# Experiment 1: seed=0, ratio=0.6, range_small=(5, 30), range_large=(80, 110), w=0.5, c1=1.0, c2=1.0 => initial=273, final=268, improve=5

# %%
# Pojemność pudełek
BIN_CAPACITY = 180

# Losowa, ale zdeterminowana lista wag: 1000 elementów (60% małych, 40% dużych)
np.random.seed(0)
small_items = np.random.randint(5, 30, size=600)
large_items = np.random.randint(80, 110, size=400)
ITEM_WEIGHTS = np.concatenate([small_items, large_items])
np.random.shuffle(ITEM_WEIGHTS)
ITEM_WEIGHTS = ITEM_WEIGHTS.tolist()

# Liczba przedmiotów
NUM_ITEMS = len(ITEM_WEIGHTS)

print(f"Liczba elementów: {NUM_ITEMS}")
print(f"Pierwsze 10 wag: {ITEM_WEIGHTS[:10]}")
# Out:
# Liczba elementów: 1000
# Pierwsze 10 wag: [18, 17, 106, 107, 5, 91, 8, 7, 99, 6]

# %% [markdown]
# # Algorytm roju

# %%
# 🎯 Funkcja dekodująca permutację do rozwiązania bin packing (heurystyka First Fit)
# Dla zadanej permutacji elementów pakuje je kolejno do pojemników tak,
# by zmieściły się bez przekroczenia pojemności BIN_CAPACITY.
def first_fit(permutation):
    bins = []
    for index in permutation:
        item = ITEM_WEIGHTS[index]
        placed = False
        for bin in bins:
            if sum(bin) + item <= BIN_CAPACITY:
                bin.append(item)
                placed = True
                break
        if not placed:
            bins.append([item])
    return bins


# 🐝 Klasa cząstki (particle) używana w algorytmie PSO
class Particle:
    def __init__(self, num_items):
        # Losowa permutacja elementów — to aktualna propozycja rozwiązania
        self.position = list(np.random.permutation(num_items))
        self.velocity = []  # lista ruchów (zamian pozycji w permutacji)
        self.best_position = self.position.copy()  # najlepsza znana permutacja dla tej cząstki
        self.best_cost = self.evaluate(self.position)  # liczba użytych pojemników dla tej permutacji

    # Funkcja celu: liczba pojemników potrzebnych dla danej permutacji
    def evaluate(self, position):
        bins = first_fit(position)
        return len(bins)

    # Aktualizacja "prędkości" (czyli zestawu zamian indeksów, które przybliżają nas do najlepszego rozwiązania)
    def update_velocity(self, global_best_position, w=0.5, c1=1.0, c2=1.0):
        swaps = []

        for i in range(NUM_ITEMS):
            # Zamiana w kierunku własnego najlepszego rozwiązania (eksploatacja)
            if random.random() < c1 and self.position[i] != self.best_position[i]:
                j = self.position.index(self.best_position[i])
                swaps.append((i, j))

            # Zamiana w kierunku najlepszego globalnego rozwiązania (eksploracja)
            if random.random() < c2 and self.position[i] != global_best_position[i]:
                j = self.position.index(global_best_position[i])
                swaps.append((i, j))

        random.shuffle(swaps)
        self.velocity = swaps[:20]  # ograniczamy liczbę zmian w jednej iteracji (siła ruchu)

    # Zastosowanie velocity do pozycji cząstki (czyli faktyczne wykonanie zamian)
    def apply_velocity(self):
        for i, j in self.velocity:
            self.position[i], self.position[j] = self.position[j], self.position[i]

    # Sprawdzenie czy nowe położenie jest lepsze — jeśli tak, aktualizujemy pamięć cząstki
    def update_personal_best(self):
        cost = self.evaluate(self.position)
        if cost < self.best_cost:
            self.best_cost = cost
            self.best_position = self.position.copy()


# 🐦 Główna funkcja algorytmu PSO dla problemu bin packing
def bin_packing_pso(num_particles=80, max_iter=200):
    start_time = time.time()

    # Inicjalizacja populacji cząstek (każda z losową permutacją)
    swarm = [Particle(NUM_ITEMS) for _ in range(num_particles)]

    # Wyznaczamy najlepszą początkową cząstkę w całym roju
    global_best = min(swarm, key=lambda p: p.best_cost)
    global_best_position = global_best.best_position.copy()
    global_best_cost = global_best.best_cost

    # Główna pętla optymalizacji
    for iteration in range(max_iter):
        for particle in swarm:
            particle.update_velocity(global_best_position)  # wyznacz ruch
            particle.apply_velocity()                      # wykonaj ruch
            particle.update_personal_best()                # aktualizuj najlepsze lokalne

        # Po aktualizacji wszystkich cząstek — sprawdź, czy któraś poprawiła globalne minimum
        best_candidate = min(swarm, key=lambda p: p.best_cost)
        if best_candidate.best_cost < global_best_cost:
            global_best_cost = best_candidate.best_cost
            global_best_position = best_candidate.best_position.copy()

        print(f"Iteracja {iteration+1}: najlepsza liczba pojemników = {global_best_cost}")

    end_time = time.time()
    final_bins = first_fit(global_best_position)

    # 📋 Zwrot wyniku jako słownik
    result = {
        "number_of_bins": len(final_bins),
        "bin_contents": final_bins,
        "execution_time_seconds": round(end_time - start_time, 2)
    }
    return result

# %%
# ▶️ Uruchomienie algorytmu
result = bin_packing_pso()

# 🖨️ Prezentacja wyniku
print("\n📦 Ostateczny wynik algorytmu PSO (Bin Packing):")
print(f"🔢 Liczba użytych pojemników: {result['number_of_bins']}")
print(f"⏱️ Czas wykonania: {result['execution_time_seconds']} s\n")
for i, bin in enumerate(result['bin_contents']):
    print(f"🗃️ Pojemnik {i+1}: {bin} (suma: {sum(bin)})")
# Out:
# Iteracja 1: najlepsza liczba pojemników = 273
# Iteracja 2: najlepsza liczba pojemników = 273
# Iteracja 3: najlepsza liczba pojemników = 273
# Iteracja 4: najlepsza liczba pojemników = 273
# Iteracja 5: najlepsza liczba pojemników = 272
# Iteracja 6: najlepsza liczba pojemników = 272
# Iteracja 7: najlepsza liczba pojemników = 272
# Iteracja 8: najlepsza liczba pojemników = 272
# Iteracja 9: najlepsza liczba pojemników = 272
# Iteracja 10: najlepsza liczba pojemników = 272
# Iteracja 11: najlepsza liczba pojemników = 272
# Iteracja 12: najlepsza liczba pojemników = 272
# Iteracja 13: najlepsza liczba pojemników = 272
# Iteracja 14: najlepsza liczba pojemników = 272
# Iteracja 15: najlepsza liczba pojemników = 271
# Iteracja 16: najlepsza liczba pojemników = 271
# Iteracja 17: najlepsza liczba pojemników = 271
# Iteracja 18: najlepsza liczba pojemników = 271
# Iteracja 19: najlepsza liczba pojemników = 271
# Iteracja 20: najlepsza liczba pojemników = 271
# Iteracja 21: najlepsza liczba pojemników = 271
# Iteracja 22: najlepsza liczba pojemników = 271
# Iteracja 23: najlepsza liczba pojemników = 271
# Iteracja 24: najlepsza liczba pojemników = 271
# Iteracja 25: najlepsza liczba pojemników = 271
# Iteracja 26: najlepsza liczba pojemników = 271
# Iteracja 27: najlepsza liczba pojemników = 271
# Iteracja 28: najlepsza liczba pojemników = 271
# Iteracja 29: najlepsza liczba pojemników = 271
# Iteracja 30: najlepsza liczba pojemników = 271
# Iteracja 31: najlepsza liczba pojemników = 271
# Iteracja 32: najlepsza liczba pojemników = 270
# Iteracja 33: najlepsza liczba pojemników = 270
# Iteracja 34: najlepsza liczba pojemników = 270
# Iteracja 35: najlepsza liczba pojemników = 270
# Iteracja 36: najlepsza liczba pojemników = 270
# Iteracja 37: najlepsza liczba pojemników = 270
# Iteracja 38: najlepsza liczba pojemników = 270
# Iteracja 39: najlepsza liczba pojemników = 270
# Iteracja 40: najlepsza liczba pojemników = 270
# Iteracja 41: najlepsza liczba pojemników = 270
# Iteracja 42: najlepsza liczba pojemników = 270
# Iteracja 43: najlepsza liczba pojemników = 270
# Iteracja 44: najlepsza liczba pojemników = 270
# Iteracja 45: najlepsza liczba pojemników = 270
# Iteracja 46: najlepsza liczba pojemników = 270
# Iteracja 47: najlepsza liczba pojemników = 270
# Iteracja 48: najlepsza liczba pojemników = 270
# Iteracja 49: najlepsza liczba pojemników = 270
# Iteracja 50: najlepsza liczba pojemników = 270
# Iteracja 51: najlepsza liczba pojemników = 270
# Iteracja 52: najlepsza liczba pojemników = 270
# Iteracja 53: najlepsza liczba pojemników = 270
# Iteracja 54: najlepsza liczba pojemników = 270
# Iteracja 55: najlepsza liczba pojemników = 270
# Iteracja 56: najlepsza liczba pojemników = 270
# Iteracja 57: najlepsza liczba pojemników = 270
# Iteracja 58: najlepsza liczba pojemników = 270
# Iteracja 59: najlepsza liczba pojemników = 270
# Iteracja 60: najlepsza liczba pojemników = 270
# Iteracja 61: najlepsza liczba pojemników = 270
# Iteracja 62: najlepsza liczba pojemników = 270
# Iteracja 63: najlepsza liczba pojemników = 270
# Iteracja 64: najlepsza liczba pojemników = 270
# Iteracja 65: najlepsza liczba pojemników = 270
# Iteracja 66: najlepsza liczba pojemników = 270
# Iteracja 67: najlepsza liczba pojemników = 270
# Iteracja 68: najlepsza liczba pojemników = 270
# Iteracja 69: najlepsza liczba pojemników = 270
# Iteracja 70: najlepsza liczba pojemników = 270
# Iteracja 71: najlepsza liczba pojemników = 270
# Iteracja 72: najlepsza liczba pojemników = 270
# Iteracja 73: najlepsza liczba pojemników = 270
# Iteracja 74: najlepsza liczba pojemników = 270
# Iteracja 75: najlepsza liczba pojemników = 270
# Iteracja 76: najlepsza liczba pojemników = 270
# Iteracja 77: najlepsza liczba pojemników = 270
# Iteracja 78: najlepsza liczba pojemników = 270
# Iteracja 79: najlepsza liczba pojemników = 270
# Iteracja 80: najlepsza liczba pojemników = 270
# Iteracja 81: najlepsza liczba pojemników = 270
# Iteracja 82: najlepsza liczba pojemników = 270
# Iteracja 83: najlepsza liczba pojemników = 270
# Iteracja 84: najlepsza liczba pojemników = 269
# Iteracja 85: najlepsza liczba pojemników = 269
# Iteracja 86: najlepsza liczba pojemników = 269
# Iteracja 87: najlepsza liczba pojemników = 269
# Iteracja 88: najlepsza liczba pojemników = 269
# Iteracja 89: najlepsza liczba pojemników = 269
# Iteracja 90: najlepsza liczba pojemników = 269
# Iteracja 91: najlepsza liczba pojemników = 269
# Iteracja 92: najlepsza liczba pojemników = 269
# Iteracja 93: najlepsza liczba pojemników = 269
# Iteracja 94: najlepsza liczba pojemników = 269
# Iteracja 95: najlepsza liczba pojemników = 269
# Iteracja 96: najlepsza liczba pojemników = 269
# Iteracja 97: najlepsza liczba pojemników = 269
# Iteracja 98: najlepsza liczba pojemników = 269
# Iteracja 99: najlepsza liczba pojemników = 269
# Iteracja 100: najlepsza liczba pojemników = 269
# Iteracja 101: najlepsza liczba pojemników = 269
# Iteracja 102: najlepsza liczba pojemników = 269
# Iteracja 103: najlepsza liczba pojemników = 269
# Iteracja 104: najlepsza liczba pojemników = 269
# Iteracja 105: najlepsza liczba pojemników = 269
# Iteracja 106: najlepsza liczba pojemników = 269
# Iteracja 107: najlepsza liczba pojemników = 269
# Iteracja 108: najlepsza liczba pojemników = 269
# Iteracja 109: najlepsza liczba pojemników = 269
# Iteracja 110: najlepsza liczba pojemników = 269
# Iteracja 111: najlepsza liczba pojemników = 269
# Iteracja 112: najlepsza liczba pojemników = 269
# Iteracja 113: najlepsza liczba pojemników = 269
# Iteracja 114: najlepsza liczba pojemników = 269
# Iteracja 115: najlepsza liczba pojemników = 269
# Iteracja 116: najlepsza liczba pojemników = 269
# Iteracja 117: najlepsza liczba pojemników = 269
# Iteracja 118: najlepsza liczba pojemników = 269
# Iteracja 119: najlepsza liczba pojemników = 269
# Iteracja 120: najlepsza liczba pojemników = 269
# Iteracja 121: najlepsza liczba pojemników = 269
# Iteracja 122: najlepsza liczba pojemników = 269
# Iteracja 123: najlepsza liczba pojemników = 269
# Iteracja 124: najlepsza liczba pojemników = 268
# Iteracja 125: najlepsza liczba pojemników = 268
# Iteracja 126: najlepsza liczba pojemników = 268
# Iteracja 127: najlepsza liczba pojemników = 268
# Iteracja 128: najlepsza liczba pojemników = 268
# Iteracja 129: najlepsza liczba pojemników = 268
# Iteracja 130: najlepsza liczba pojemników = 268
# Iteracja 131: najlepsza liczba pojemników = 268
# Iteracja 132: najlepsza liczba pojemników = 268
# Iteracja 133: najlepsza liczba pojemników = 268
# Iteracja 134: najlepsza liczba pojemników = 268
# Iteracja 135: najlepsza liczba pojemników = 268
# Iteracja 136: najlepsza liczba pojemników = 268
# Iteracja 137: najlepsza liczba pojemników = 268
# Iteracja 138: najlepsza liczba pojemników = 268
# Iteracja 139: najlepsza liczba pojemników = 268
# Iteracja 140: najlepsza liczba pojemników = 268
# Iteracja 141: najlepsza liczba pojemników = 268
# Iteracja 142: najlepsza liczba pojemników = 268
# Iteracja 143: najlepsza liczba pojemników = 268
# Iteracja 144: najlepsza liczba pojemników = 268
# Iteracja 145: najlepsza liczba pojemników = 268
# Iteracja 146: najlepsza liczba pojemników = 268
# Iteracja 147: najlepsza liczba pojemników = 268
# Iteracja 148: najlepsza liczba pojemników = 268
# Iteracja 149: najlepsza liczba pojemników = 268
# Iteracja 150: najlepsza liczba pojemników = 268
# Iteracja 151: najlepsza liczba pojemników = 268
# Iteracja 152: najlepsza liczba pojemników = 268
# Iteracja 153: najlepsza liczba pojemników = 268
# Iteracja 154: najlepsza liczba pojemników = 268
# Iteracja 155: najlepsza liczba pojemników = 268
# Iteracja 156: najlepsza liczba pojemników = 268
# Iteracja 157: najlepsza liczba pojemników = 268
# Iteracja 158: najlepsza liczba pojemników = 268
# Iteracja 159: najlepsza liczba pojemników = 268
# Iteracja 160: najlepsza liczba pojemników = 268
# Iteracja 161: najlepsza liczba pojemników = 268
# Iteracja 162: najlepsza liczba pojemników = 268
# Iteracja 163: najlepsza liczba pojemników = 268
# Iteracja 164: najlepsza liczba pojemników = 268
# Iteracja 165: najlepsza liczba pojemników = 268
# Iteracja 166: najlepsza liczba pojemników = 268
# Iteracja 167: najlepsza liczba pojemników = 268
# Iteracja 168: najlepsza liczba pojemników = 268
# Iteracja 169: najlepsza liczba pojemników = 268
# Iteracja 170: najlepsza liczba pojemników = 268
# Iteracja 171: najlepsza liczba pojemników = 268
# Iteracja 172: najlepsza liczba pojemników = 268
# Iteracja 173: najlepsza liczba pojemników = 268
# Iteracja 174: najlepsza liczba pojemników = 268
# Iteracja 175: najlepsza liczba pojemników = 268
# Iteracja 176: najlepsza liczba pojemników = 268
# Iteracja 177: najlepsza liczba pojemników = 268
# Iteracja 178: najlepsza liczba pojemników = 268
# Iteracja 179: najlepsza liczba pojemników = 268
# Iteracja 180: najlepsza liczba pojemników = 268
# Iteracja 181: najlepsza liczba pojemników = 268
# Iteracja 182: najlepsza liczba pojemników = 268
# Iteracja 183: najlepsza liczba pojemników = 268
# Iteracja 184: najlepsza liczba pojemników = 268
# Iteracja 185: najlepsza liczba pojemników = 267
# Iteracja 186: najlepsza liczba pojemników = 267
# Iteracja 187: najlepsza liczba pojemników = 267
# Iteracja 188: najlepsza liczba pojemników = 267
# Iteracja 189: najlepsza liczba pojemników = 267
# Iteracja 190: najlepsza liczba pojemników = 267
# Iteracja 191: najlepsza liczba pojemników = 267
# Iteracja 192: najlepsza liczba pojemników = 267
# Iteracja 193: najlepsza liczba pojemników = 267
# Iteracja 194: najlepsza liczba pojemników = 267
# Iteracja 195: najlepsza liczba pojemników = 267
# Iteracja 196: najlepsza liczba pojemników = 267
# Iteracja 197: najlepsza liczba pojemników = 267
# Iteracja 198: najlepsza liczba pojemników = 267
# Iteracja 199: najlepsza liczba pojemników = 267
# Iteracja 200: najlepsza liczba pojemników = 267
#
# 📦 Ostateczny wynik algorytmu PSO (Bin Packing):
# 🔢 Liczba użytych pojemników: 267
# ⏱️ Czas wykonania: 511.76 s
#
# 🗃️ Pojemnik 1: [89, 7, 23, 26, 29, 6] (suma: 180)
# 🗃️ Pojemnik 2: [98, 8, 25, 22, 24] (suma: 177)
# 🗃️ Pojemnik 262: [91, 85] (suma: 176)
# 🗃️ Pojemnik 263: [104, 25, 18, 15, 16] (suma: 178)
# 🗃️ Pojemnik 264: [92, 85] (suma: 177)
# 🗃️ Pojemnik 265: [94, 81, 5] (suma: 180)
# 🗃️ Pojemnik 266: [99, 20, 24, 23, 10] (suma: 176)
# 🗃️ Pojemnik 267: [100, 5, 17, 12, 17, 9, 14, 5] (suma: 179)

# %% [markdown]
# # Algorytm genetyczny

# %%
# 🧬 ALGORYTM GENETYCZNY DLA BIN PACKING

def evaluate_solution(permutation):
    return len(first_fit(permutation))

def tournament_selection(population, fitnesses, tournament_size=3):
    selected = random.sample(list(zip(population, fitnesses)), tournament_size)
    selected.sort(key=lambda x: x[1])
    return selected[0][0]

# ✅ Poprawiona wersja order_crossover
def order_crossover(parent1, parent2):
    size = len(parent1)
    start, end = sorted(random.sample(range(size), 2))

    child = [None] * size
    child[start:end] = parent1[start:end]

    inserted = set(child[start:end])
    current_index = end

    for i in range(size):
        gene = parent2[(end + i) % size]
        if gene not in inserted:
            child[current_index % size] = gene
            current_index += 1
            inserted.add(gene)

    return child

def mutate(permutation, mutation_rate=0.05):
    for i in range(len(permutation)):
        if random.random() < mutation_rate:
            j = random.randint(0, len(permutation) - 1)
            permutation[i], permutation[j] = permutation[j], permutation[i]

def bin_packing_genetic_algorithm(
    population_size=100,
    generations=200,
    crossover_rate=0.9,
    mutation_rate=0.05
):
    start_time = time.time()

    # 🔄 Inicjalizacja populacji
    population = [list(np.random.permutation(NUM_ITEMS)) for _ in range(population_size)]
    fitnesses = [evaluate_solution(ind) for ind in population]

    best_idx = np.argmin(fitnesses)
    best_solution = population[best_idx]
    best_cost = fitnesses[best_idx]

    for generation in range(generations):
        new_population = []

        while len(new_population) < population_size:
            # 🧬 Selekcja
            parent1 = tournament_selection(population, fitnesses)
            parent2 = tournament_selection(population, fitnesses)

            # 🔗 Krzyżowanie
            if random.random() < crossover_rate:
                child = order_crossover(parent1, parent2)
            else:
                child = parent1.copy()

            # 🌀 Mutacja
            mutate(child, mutation_rate)

            new_population.append(child)

        population = new_population
        fitnesses = [evaluate_solution(ind) for ind in population]

        best_idx = np.argmin(fitnesses)
        if fitnesses[best_idx] < best_cost:
            best_solution = population[best_idx]
            best_cost = fitnesses[best_idx]

        print(f"Generacja {generation+1}: najlepsza liczba pojemników = {best_cost}")

    end_time = time.time()
    final_bins = first_fit(best_solution)

    return {
        "number_of_bins": len(final_bins),
        "bin_contents": final_bins,
        "execution_time_seconds": round(end_time - start_time, 2)
    }

# ▶️ Uruchomienie algorytmu genetycznego
result = bin_packing_genetic_algorithm()

# 🖨️ Prezentacja wyniku
print("\n📦 Ostateczny wynik algorytmu genetycznego (Bin Packing):")
print(f"🔢 Liczba użytych pojemników: {result['number_of_bins']}")
print(f"⏱️ Czas wykonania: {result['execution_time_seconds']} s\n")
for i, bin in enumerate(result['bin_contents']):
    print(f"🗃️ Pojemnik {i+1}: {bin} (suma: {sum(bin)})")
# Out:
# Generacja 1: najlepsza liczba pojemników = 271
# Generacja 2: najlepsza liczba pojemników = 271
# Generacja 3: najlepsza liczba pojemników = 271
# Generacja 4: najlepsza liczba pojemników = 270
# Generacja 5: najlepsza liczba pojemników = 270
# Generacja 6: najlepsza liczba pojemników = 270
# Generacja 7: najlepsza liczba pojemników = 270
# Generacja 8: najlepsza liczba pojemników = 270
# Generacja 9: najlepsza liczba pojemników = 270
# Generacja 10: najlepsza liczba pojemników = 270
# Generacja 11: najlepsza liczba pojemników = 270
# Generacja 12: najlepsza liczba pojemników = 270
# Generacja 13: najlepsza liczba pojemników = 270
# Generacja 14: najlepsza liczba pojemników = 270
# Generacja 15: najlepsza liczba pojemników = 270
# Generacja 16: najlepsza liczba pojemników = 270
# Generacja 17: najlepsza liczba pojemników = 270
# Generacja 18: najlepsza liczba pojemników = 270
# Generacja 19: najlepsza liczba pojemników = 270
# Generacja 20: najlepsza liczba pojemników = 270
# Generacja 21: najlepsza liczba pojemników = 270
# Generacja 22: najlepsza liczba pojemników = 270
# Generacja 23: najlepsza liczba pojemników = 270
# Generacja 24: najlepsza liczba pojemników = 269
# Generacja 25: najlepsza liczba pojemników = 269
# Generacja 26: najlepsza liczba pojemników = 269
# Generacja 27: najlepsza liczba pojemników = 269
# Generacja 28: najlepsza liczba pojemników = 269
# Generacja 29: najlepsza liczba pojemników = 269
# Generacja 30: najlepsza liczba pojemników = 269
# Generacja 31: najlepsza liczba pojemników = 269
# Generacja 32: najlepsza liczba pojemników = 269
# Generacja 33: najlepsza liczba pojemników = 269
# Generacja 34: najlepsza liczba pojemników = 269
# Generacja 35: najlepsza liczba pojemników = 269
# Generacja 36: najlepsza liczba pojemników = 269
# Generacja 37: najlepsza liczba pojemników = 269
# Generacja 38: najlepsza liczba pojemników = 269
# Generacja 39: najlepsza liczba pojemników = 269
# Generacja 40: najlepsza liczba pojemników = 269
# Generacja 41: najlepsza liczba pojemników = 269
# Generacja 42: najlepsza liczba pojemników = 269
# Generacja 43: najlepsza liczba pojemników = 269
# Generacja 44: najlepsza liczba pojemników = 269
# Generacja 45: najlepsza liczba pojemników = 269
# Generacja 46: najlepsza liczba pojemników = 269
# Generacja 47: najlepsza liczba pojemników = 269
# Generacja 48: najlepsza liczba pojemników = 269
# Generacja 49: najlepsza liczba pojemników = 269
# Generacja 50: najlepsza liczba pojemników = 269
# Generacja 51: najlepsza liczba pojemników = 269
# Generacja 52: najlepsza liczba pojemników = 269
# Generacja 53: najlepsza liczba pojemników = 269
# Generacja 54: najlepsza liczba pojemników = 269
# Generacja 55: najlepsza liczba pojemników = 269
# Generacja 56: najlepsza liczba pojemników = 269
# Generacja 57: najlepsza liczba pojemników = 269
# Generacja 58: najlepsza liczba pojemników = 269
# Generacja 59: najlepsza liczba pojemników = 269
# Generacja 60: najlepsza liczba pojemników = 269
# Generacja 61: najlepsza liczba pojemników = 269
# Generacja 62: najlepsza liczba pojemników = 269
# Generacja 63: najlepsza liczba pojemników = 269
# Generacja 64: najlepsza liczba pojemników = 269
# Generacja 65: najlepsza liczba pojemników = 269
# Generacja 66: najlepsza liczba pojemników = 269
# Generacja 67: najlepsza liczba pojemników = 269
# Generacja 68: najlepsza liczba pojemników = 269
# Generacja 69: najlepsza liczba pojemników = 269
# Generacja 70: najlepsza liczba pojemników = 269
# Generacja 71: najlepsza liczba pojemników = 269
# Generacja 72: najlepsza liczba pojemników = 269
# Generacja 73: najlepsza liczba pojemników = 269
# Generacja 74: najlepsza liczba pojemników = 269
# Generacja 75: najlepsza liczba pojemników = 269
# Generacja 76: najlepsza liczba pojemników = 269
# Generacja 77: najlepsza liczba pojemników = 269
# Generacja 78: najlepsza liczba pojemników = 269
# Generacja 79: najlepsza liczba pojemników = 269
# Generacja 80: najlepsza liczba pojemników = 269
# Generacja 81: najlepsza liczba pojemników = 269
# Generacja 82: najlepsza liczba pojemników = 269
# Generacja 83: najlepsza liczba pojemników = 269
# Generacja 84: najlepsza liczba pojemników = 269
# Generacja 85: najlepsza liczba pojemników = 269
# Generacja 86: najlepsza liczba pojemników = 269
# Generacja 87: najlepsza liczba pojemników = 269
# Generacja 88: najlepsza liczba pojemników = 269
# Generacja 89: najlepsza liczba pojemników = 269
# Generacja 90: najlepsza liczba pojemników = 269
# Generacja 91: najlepsza liczba pojemników = 269
# Generacja 92: najlepsza liczba pojemników = 269
# Generacja 93: najlepsza liczba pojemników = 269
# Generacja 94: najlepsza liczba pojemników = 269
# Generacja 95: najlepsza liczba pojemników = 269
# Generacja 96: najlepsza liczba pojemników = 269
# Generacja 97: najlepsza liczba pojemników = 269
# Generacja 98: najlepsza liczba pojemników = 269
# Generacja 99: najlepsza liczba pojemników = 269
# Generacja 100: najlepsza liczba pojemników = 269
# Generacja 101: najlepsza liczba pojemników = 269
# Generacja 102: najlepsza liczba pojemników = 269
# Generacja 103: najlepsza liczba pojemników = 269
# Generacja 104: najlepsza liczba pojemników = 269
# Generacja 105: najlepsza liczba pojemników = 269
# Generacja 106: najlepsza liczba pojemników = 269
# Generacja 107: najlepsza liczba pojemników = 269
# Generacja 108: najlepsza liczba pojemników = 269
# Generacja 109: najlepsza liczba pojemników = 269
# Generacja 110: najlepsza liczba pojemników = 269
# Generacja 111: najlepsza liczba pojemników = 269
# Generacja 112: najlepsza liczba pojemników = 269
# Generacja 113: najlepsza liczba pojemników = 269
# Generacja 114: najlepsza liczba pojemników = 269
# Generacja 115: najlepsza liczba pojemników = 269
# Generacja 116: najlepsza liczba pojemników = 269
# Generacja 117: najlepsza liczba pojemników = 269
# Generacja 118: najlepsza liczba pojemników = 269
# Generacja 119: najlepsza liczba pojemników = 269
# Generacja 120: najlepsza liczba pojemników = 269
# Generacja 121: najlepsza liczba pojemników = 269
# Generacja 122: najlepsza liczba pojemników = 269
# Generacja 123: najlepsza liczba pojemników = 269
# Generacja 124: najlepsza liczba pojemników = 269
# Generacja 125: najlepsza liczba pojemników = 269
# Generacja 126: najlepsza liczba pojemników = 269
# Generacja 127: najlepsza liczba pojemników = 269
# Generacja 128: najlepsza liczba pojemników = 269
# Generacja 129: najlepsza liczba pojemników = 269
# Generacja 130: najlepsza liczba pojemników = 269
# Generacja 131: najlepsza liczba pojemników = 269
# Generacja 132: najlepsza liczba pojemników = 269
# Generacja 133: najlepsza liczba pojemników = 269
# Generacja 134: najlepsza liczba pojemników = 269
# Generacja 135: najlepsza liczba pojemników = 269
# Generacja 136: najlepsza liczba pojemników = 269
# Generacja 137: najlepsza liczba pojemników = 269
# Generacja 138: najlepsza liczba pojemników = 269
# Generacja 139: najlepsza liczba pojemników = 269
# Generacja 140: najlepsza liczba pojemników = 269
# Generacja 141: najlepsza liczba pojemników = 269
# Generacja 142: najlepsza liczba pojemników = 269
# Generacja 143: najlepsza liczba pojemników = 269
# Generacja 144: najlepsza liczba pojemników = 269
# Generacja 145: najlepsza liczba pojemników = 269
# Generacja 146: najlepsza liczba pojemników = 269
# Generacja 147: najlepsza liczba pojemników = 269
# Generacja 148: najlepsza liczba pojemników = 269
# Generacja 149: najlepsza liczba pojemników = 269
# Generacja 150: najlepsza liczba pojemników = 269
# Generacja 151: najlepsza liczba pojemników = 269
# Generacja 152: najlepsza liczba pojemników = 269
# Generacja 153: najlepsza liczba pojemników = 269
# Generacja 154: najlepsza liczba pojemników = 269
# Generacja 155: najlepsza liczba pojemników = 269
# Generacja 156: najlepsza liczba pojemników = 269
# Generacja 157: najlepsza liczba pojemników = 269
# Generacja 158: najlepsza liczba pojemników = 269
# Generacja 159: najlepsza liczba pojemników = 269
# Generacja 160: najlepsza liczba pojemników = 269
# Generacja 161: najlepsza liczba pojemników = 269
# Generacja 162: najlepsza liczba pojemników = 269
# Generacja 163: najlepsza liczba pojemników = 269
# Generacja 164: najlepsza liczba pojemników = 269
# Generacja 165: najlepsza liczba pojemników = 269
# Generacja 166: najlepsza liczba pojemników = 269
# Generacja 167: najlepsza liczba pojemników = 269
# Generacja 168: najlepsza liczba pojemników = 269
# Generacja 169: najlepsza liczba pojemników = 269
# Generacja 170: najlepsza liczba pojemników = 269
# Generacja 171: najlepsza liczba pojemników = 269
# Generacja 172: najlepsza liczba pojemników = 269
# Generacja 173: najlepsza liczba pojemników = 269
# Generacja 174: najlepsza liczba pojemników = 269
# Generacja 175: najlepsza liczba pojemników = 269
# Generacja 176: najlepsza liczba pojemników = 269
# Generacja 177: najlepsza liczba pojemników = 269
# Generacja 178: najlepsza liczba pojemników = 269
# Generacja 179: najlepsza liczba pojemników = 269
# Generacja 180: najlepsza liczba pojemników = 269
# Generacja 181: najlepsza liczba pojemników = 269
# Generacja 182: najlepsza liczba pojemników = 269
# Generacja 183: najlepsza liczba pojemników = 269
# Generacja 184: najlepsza liczba pojemników = 269
# Generacja 185: najlepsza liczba pojemników = 269
# Generacja 186: najlepsza liczba pojemników = 269
# Generacja 187: najlepsza liczba pojemników = 269
# Generacja 188: najlepsza liczba pojemników = 269
# Generacja 189: najlepsza liczba pojemników = 269
# 🗃️ Pojemnik 248: [108, 25, 13, 26, 7] (suma: 179)
# 🗃️ Pojemnik 249: [104, 20, 11, 14, 27] (suma: 176)
# 🗃️ Pojemnik 250: [90, 89] (suma: 179)
# 🗃️ Pojemnik 251: [95, 81] (suma: 176)
# 🗃️ Pojemnik 252: [89, 80, 9] (suma: 178)
# 🗃️ Pojemnik 253: [98, 81] (suma: 179)
# 🗃️ Pojemnik 254: [83, 92] (suma: 175)
# 🗃️ Pojemnik 255: [101, 18, 18, 16, 22] (suma: 175)
# 🗃️ Pojemnik 256: [102, 26, 15, 11, 12, 8] (suma: 174)
# 🗃️ Pojemnik 257: [100, 26, 22, 28] (suma: 176)
# 🗃️ Pojemnik 258: [99, 81] (suma: 180)
# 🗃️ Pojemnik 259: [102, 18, 19, 9, 8, 23] (suma: 179)
# 🗃️ Pojemnik 260: [83, 96] (suma: 179)
# 🗃️ Pojemnik 261: [81, 97] (suma: 178)
# 🗃️ Pojemnik 262: [107] (suma: 107)
# 🗃️ Pojemnik 263: [95, 85] (suma: 180)
# 🗃️ Pojemnik 264: [92, 88] (suma: 180)
# 🗃️ Pojemnik 265: [94, 86] (suma: 180)
# 🗃️ Pojemnik 266: [105] (suma: 105)
# 🗃️ Pojemnik 267: [105] (suma: 105)
# 🗃️ Pojemnik 268: [104] (suma: 104)
# 🗃️ Pojemnik 269: [96, 84] (suma: 180)

# %% [markdown]
# # ALGORYTM SA

# %%
import numpy as np
import random
import time

BIN_CAPACITY = 180
np.random.seed(0)
small_items = np.random.randint(5, 30, size=600)
large_items = np.random.randint(80, 110, size=400)
ITEM_WEIGHTS = np.concatenate([small_items, large_items])
np.random.shuffle(ITEM_WEIGHTS)
ITEM_WEIGHTS = ITEM_WEIGHTS.tolist()
NUM_ITEMS = len(ITEM_WEIGHTS)

# Funkcja first-fit
def first_fit(permutation):
    bins = []
    for index in permutation:
        item = ITEM_WEIGHTS[index]
        placed = False
        for bin in bins:
            if sum(bin) + item <= BIN_CAPACITY:
                bin.append(item)
                placed = True
                break
        if not placed:
            bins.append([item])
    return bins

# Simulated Annealing dla Bin Packing
def bin_packing_sa(max_iter=10000, initial_temp=100.0, cooling_rate=0.995):
    start_time = time.time()

    # Start: losowa permutacja
    current_solution = list(np.random.permutation(NUM_ITEMS))
    current_cost = len(first_fit(current_solution))

    best_solution = current_solution.copy()
    best_cost = current_cost

    temperature = initial_temp

    for iteration in range(max_iter):
        # Tworzymy nowego kandydata przez zamianę dwóch losowych elementów
        candidate_solution = current_solution.copy()
        i, j = random.sample(range(NUM_ITEMS), 2)
        candidate_solution[i], candidate_solution[j] = candidate_solution[j], candidate_solution[i]

        candidate_cost = len(first_fit(candidate_solution))

        # Czy zaakceptować nowe rozwiązanie?
        cost_diff = candidate_cost - current_cost
        if cost_diff < 0 or random.random() < np.exp(-cost_diff / temperature):
            current_solution = candidate_solution
            current_cost = candidate_cost

            # Aktualizacja najlepszego znalezionego rozwiązania
            if current_cost < best_cost:
                best_solution = current_solution.copy()
                best_cost = current_cost

        # Schładzanie
        temperature *= cooling_rate

        # Opcjonalny print co 1000 iteracji
        if iteration % 1000 == 0:
            print(f"Iteracja {iteration}: Najlepsza liczba pojemników = {best_cost}")

    end_time = time.time()
    final_bins = first_fit(best_solution)

    result = {
        "number_of_bins": len(final_bins),
        "bin_contents": final_bins,
        "execution_time_seconds": round(end_time - start_time, 2)
    }
    return result

# PRZYKŁAD UŻYCIA:
if __name__ == "__main__":
    result = bin_packing_sa()
    print("\n--- WYNIK SA ---")
    print(f"Liczba pojemników: {result['number_of_bins']}")
    print(f"Czas działania: {result['execution_time_seconds']} sekund")
# Out:
# Iteracja 0: Najlepsza liczba pojemników = 278
# Iteracja 1000: Najlepsza liczba pojemników = 275
# Iteracja 2000: Najlepsza liczba pojemników = 268
# Iteracja 3000: Najlepsza liczba pojemników = 268
# Iteracja 4000: Najlepsza liczba pojemników = 268
# Iteracja 5000: Najlepsza liczba pojemników = 268
# Iteracja 6000: Najlepsza liczba pojemników = 267
# Iteracja 7000: Najlepsza liczba pojemników = 267
# Iteracja 8000: Najlepsza liczba pojemników = 267
# Iteracja 9000: Najlepsza liczba pojemników = 267
#
# --- WYNIK SA ---
# Liczba pojemników: 267
# Czas działania: 205.9 sekund

# %%
# ▶️ Uruchomienie algorytmu
result = bin_packing_sa()

# 🖨️ Prezentacja wyniku
print("\n📦 Ostateczny wynik algorytmu SA (Bin Packing):")
print(f"🔢 Liczba użytych pojemników: {result['number_of_bins']}")
print(f"⏱️ Czas wykonania: {result['execution_time_seconds']} s\n")
for i, bin in enumerate(result['bin_contents']):
    print(f"🗃️ Pojemnik {i+1}: {bin} (suma: {sum(bin)})")
# Out:
# Iteracja 0: Najlepsza liczba pojemników = 277
# Iteracja 1000: Najlepsza liczba pojemników = 271
# Iteracja 2000: Najlepsza liczba pojemników = 269
# Iteracja 3000: Najlepsza liczba pojemników = 268
# Iteracja 4000: Najlepsza liczba pojemników = 268
# Iteracja 5000: Najlepsza liczba pojemników = 268
# Iteracja 6000: Najlepsza liczba pojemników = 268
# Iteracja 7000: Najlepsza liczba pojemników = 268
# Iteracja 8000: Najlepsza liczba pojemników = 268
# Iteracja 9000: Najlepsza liczba pojemników = 268
#
# 📦 Ostateczny wynik algorytmu SA (Bin Packing):
# 🔢 Liczba użytych pojemników: 268
# ⏱️ Czas wykonania: 191.53 s
#
# 🗃️ Pojemnik 1: [12, 99, 8, 9, 24, 22, 5] (suma: 179)
# 🗃️ Pojemnik 2: [104, 11, 8, 8, 21, 28] (suma: 180)
# 🗃️ Pojemnik 3: [96, 14, 23, 16, 8, 10, 8, 5] (suma: 180)
# 🗃️ Pojemnik 4: [102, 24, 18, 8, 23, 5] (suma: 180)
# 🗃️ Pojemnik 5: [96, 10, 18, 23, 15, 15] (suma: 177)
# 🗃️ Pojemnik 6: [85, 89, 6] (suma: 180)
# 🗃️ Pojemnik 7: [105, 22, 18, 28, 7] (suma: 180)
# 🗃️ Pojemnik 8: [97, 81] (suma: 178)
